# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('epa-sea-level.csv')

# %%
df
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0    1880                  0.000000          -0.952756           0.952756
# 1    1881                  0.220472          -0.732283           1.173228
# 2    1882                 -0.440945          -1.346457           0.464567
# 3    1883                 -0.232283          -1.129921           0.665354
# 4    1884                  0.590551          -0.283465           1.464567
# ..    ...                       ...                ...                ...
# 129  2009                  8.586614           8.311024           8.862205
# 130  2010                  8.901575           8.618110           9.185039
# 131  2011                  8.964567           8.661417           9.267717
# 132  2012                  9.326772           8.992126           9.661417
# 133  2013                  8.980315           8.622047           9.338583
#
#      NOAA Adjusted Sea Level
# 0                        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      134 non-null    int64
#  1   CSIRO Adjusted Sea Level  134 non-null    float64
#  2   Lower Error Bound         134 non-null    float64
#  3   Upper Error Bound         134 non-null    float64
#  4   NOAA Adjusted Sea Level   21 non-null     float64
# dtypes: float64(4), int64(1)
# memory usage: 5.4 KB

# %%
x = df[['Year']]
y = df['CSIRO Adjusted Sea Level']

# %%
plt.scatter(x,y)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3, random_state=42)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediccionlr=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
fiabilidad=r2_score(y_test,prediccionlr)

# %%
fiabilidad
# Out:
# 0.9709299313418107

# %%
fecha_nueva = np.array([[2050]])
prediccion = lr.predict(fecha_nueva)
# Out:
# /Users/antoniojosealvarez/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
prediccion
# Out:
# array([10.25932962])

# %%
# Graficar los datos de prueba y la predicción
plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, color='blue', label='Datos de Prueba')  # Graficar los datos de prueba
plt.plot(x_test, prediccionlr, color='red', linewidth=2, label='Predicción')  # Graficar la predicción

# Etiquetas y título del gráfico
plt.xlabel('Año')
plt.ylabel('CSIRO Adjusted Sea Level')
plt.title('Predicción del Nivel del Mar con Regresión Lineal')
plt.legend()

plt.show()
