# %% [markdown]
# <a href="https://colab.research.google.com/github/antalvort/Mi-portfolio/blob/main/Datos_acciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import yfinance as yf
import pandas as pd
import json

# %%
tesla = yf.Ticker('TSLA')

# %%
data=yf.download('TSLA',period='max')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data.reset_index(inplace=True)

# %%
data.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 3 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 4 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
tesla.financials
# Out:
#                                                        2023-12-31  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                           0.21
# Normalized EBITDA                                   14796000000.0
# Total Unusual Items                                           0.0
# Total Unusual Items Excluding Goodwill                        0.0
# Net Income From Continuing Operation Net Minori...  14999000000.0
# Reconciled Depreciation                              4667000000.0
# Reconciled Cost Of Revenue                          79113000000.0
# EBITDA                                              14796000000.0
# EBIT                                                10129000000.0
# Net Interest Income                                   910000000.0
# Interest Expense                                      156000000.0
# Interest Income                                      1066000000.0
# ...

# %%
revenues=tesla.financials.loc['Total Revenue']

# %%
revenues.tail()
# Out:
# 2023-12-31    96773000000.0
# 2022-12-31    81462000000.0
# 2021-12-31    53823000000.0
# 2020-12-31    31536000000.0
# 2019-12-31              NaN
# Name: Total Revenue, dtype: object

# %%
gme=yf.Ticker('GME')

# %%
gme_data=yf.download('GME',period='max')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
gme_data.reset_index(inplace=True)

# %%
gme_data.head()
# Out:
#         Date     Open     High      Low    Close  Adj Close    Volume
# 0 2002-02-13  2.40625  2.51500  2.38125  2.51250   1.691667  76216000
# 1 2002-02-14  2.54375  2.54875  2.48125  2.50000   1.683251  11021600
# 2 2002-02-15  2.50000  2.50625  2.46250  2.48750   1.674834   8389600
# 3 2002-02-19  2.47500  2.47500  2.34375  2.38750   1.607504   7410400
# 4 2002-02-20  2.40000  2.46875  2.38125  2.46875   1.662210   6892800

# %%
gme.financials
# Out:
#                                                       2024-01-31  \
# Tax Effect Of Unusual Items                           -1920000.0
# Tax Rate For Calcs                                           0.4
# Normalized EBITDA                                     31300000.0
# Total Unusual Items                                   -4800000.0
# Total Unusual Items Excluding Goodwill                -4800000.0
# Net Income From Continuing Operation Net Minori...     6700000.0
# Reconciled Depreciation                               56200000.0
# Reconciled Cost Of Revenue                          3978600000.0
# EBITDA                                                26500000.0
# EBIT                                                 -29700000.0
# Net Interest Income                                   49500000.0
# Interest Expense                                             NaN
# Interest Income                                              NaN
# ...

# %%
revenues_gme=gme.financials.loc['Total Revenue']

# %%
revenues_gme.tail()
# Out:
# 2024-01-31    5272800000.0
# 2023-01-31    5927200000.0
# 2022-01-31    6010700000.0
# 2021-01-31    5089800000.0
# 2020-01-31             NaN
# Name: Total Revenue, dtype: object

# %%
tesla.make_graph()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-135-48c2b89f4b5d> in <cell line: 1>()
# ----> 1 tesla.make_graph()
#
# AttributeError: 'Ticker' object has no attribute 'make_graph'

# %%
import matplotlib.pyplot as plt

# %%
x=data['Date']

# %%
y=data['Adj Close']

# %%
plt.title('Tesla Stock Price History')
plt.plot(x,y)
plt.xlabel('date')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
x=gme_data['Date']
y=gme_data['Adj Close']

# %%
plt.title('Game Stop Stock Price History')
plt.plot(x,y)
plt.xlabel('date')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')
